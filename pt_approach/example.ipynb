# %%
# %matplotlib inline
# %run -i classifier.py create_model l1 cross model_weights
# Out:
# Argument List: ['classifier.py', 'create_model', 'l1', 'cross', 'model_weights']
# 1: (model persistency) create_model|load_from_file|
# 2: (model validation) train_test|cross
# 3: (feature selection) none|l1|l2
# 4: (feature analysis) model_weights|no
# num instances:  5668
# creating split...
# Build pipeline..
# fitting..
# Train classification report..
# Train Accuracy= 0.9744155271283634
#              precision    recall  f1-score   support
#
#     No hate       1.00      0.97      0.98      3567
#        Hate       0.90      1.00      0.94       967
#
# avg / total       0.98      0.97      0.97      4534
#
# Train Confusion Matrix:
#  [[3455  112]
#  [   4  963]]
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   42.9s remaining:  1.1min
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:   43.5s remaining:   29.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   43.6s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   43.6s finished
# ...

# %%
# %matplotlib inline
# %run -i classifier.py create_model none cross no_model_weights
# Out:
# Argument List: ['classifier.py', 'create_model', 'none', 'cross', 'no_model_weights']
# 1: (model persistency) create_model|load_from_file|
# 2: (model validation) train_test|cross
# 3: (feature selection) none|l1|l2
# 4: (feature analysis) model_weights|no
# num instances:  5668
# creating split...
# Build pipeline..
# fitting..
# Train classification report..
# Train Accuracy= 0.9995588883987648
#              precision    recall  f1-score   support
#
#     No hate       1.00      1.00      1.00      3567
#        Hate       1.00      1.00      1.00       967
#
# avg / total       1.00      1.00      1.00      4534
#
# Train Confusion Matrix:
#  [[3565    2]
#  [   0  967]]
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   42.7s remaining:  1.1min
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:   43.6s remaining:   29.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   43.7s remaining:    0.0s
# ...

# %%
# %matplotlib inline
# %run -i classifier.py create_model l2 cross model_weights
# Out:
# Argument List: ['classifier.py', 'create_model', 'l2', 'cross', 'model_weights']
# 1: (model persistency) create_model|load_from_file|
# 2: (model validation) train_test|cross
# 3: (feature selection) none|l1|l2
# 4: (feature analysis) model_weights|no
# num instances:  5668
# creating split...
# Build pipeline..
# fitting..
# Train classification report..
# Train Accuracy= 0.9995588883987648
#              precision    recall  f1-score   support
#
#     No hate       1.00      1.00      1.00      3567
#        Hate       1.00      1.00      1.00       967
#
# avg / total       1.00      1.00      1.00      4534
#
# Train Confusion Matrix:
#  [[3565    2]
#  [   0  967]]
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   42.7s remaining:  1.1min
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:   44.1s remaining:   29.3s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   44.3s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   44.3s finished
# ...
